# %%
import numpy as np
import cv2 as cv
import os
import matplotlib.pyplot as plt
import glob
from shapely.geometry import Point, Polygon

# %%
train = False
if train:
    images = glob.glob("./train/Task2/*.jpg")
else:
    images = glob.glob("./test/Task2/*.jpg")
images.sort()

# %%
images_t = []
for img in images:
    images_t.append(cv.imread(img))

# %%
h_s = {'b50': [(1316,1808),(1348,1820),(1352,1844),(1344,1872),(1316,1872),(1296,1852),(1300,1832)],
       'b25': [(1268,1836),(1272,1804),(1292,1784),(1332,1764),(1368,1788),(1388,1816),(1392,1852),(1380,1892),(1344,1916),
               (1296,1912),(1272,1884)],
       's1': [[(1356,1380),(1356,1424),(1352,1480),(1344,1536),(1344,1600),(1340,1652),(1336,1708),(1332,1752),(1344,1764),
               (1364,1732),(1384,1672),(1396,1632),(1412,1584),(1428,1524),(1444,1480),(1460,1440),(1468,1416),(1444,1404),
               (1408,1388)],
              [(1364,1316),(1364,1256),(1372,1184),(1380,1124),(1380,1084),(1384,1064),(1424,1076),(1464,1092),(1496,1108),
               (1532,1124),(1556,1140),(1544,1176),(1532,1228),(1516,1264),(1500,1316),(1500,1316),(1484,1364),(1408,1336),
               (1448,1352)]],
       's2': [[(1360,1924),(1360,1924),(1364,1904),(1388,1908),(1404,1924),(1436,1956),(1468,1988),(1496,2016),(1532,2064),
               (1576,2108),(1588,2120),(1576,2148),(1548,2184),(1516,2220),(1488,2176),(1468,2128),(1444,2084),(1420,2032),
               (1392,1984)],
              [(1532,2264),(1568,2228),(1596,2196),(1608,2176),(1620,2160),(1656,2188),(1684,2220),(1712,2256),(1752,2296),
               (1724,2340),(1704,2372),(1676,2412),(1632,2468),(1556,2308),(1572,2352),(1592,2384),(1608,2424)]],
       's3': [[(1332,1928),(1348,1960),(1356,2016),(1368,2080),(1388,2164),(1400,2232),(1416,2292),(1368,2308),(1320,2316),
               (1300,2316),(1304,2248),(1312,2168),(1312,2096),(1320,2024),(1320,1964)],
              [(1278,2653),(1332,2645),(1379,2631),(1425,2611),(1461,2597),(1420,2347),(1380,2362),(1344,2373),(1294,2376)]],
       's4': [[(1368,1776),(1556,1500),(1588,1532),(1608,1568),(1624,1604),(1388,1800)],
              [(1581,1459),(1696,1283),(1728,1328),(1728,1328),(1753,1367),(1772,1405),(1772,1405),(1798,1459),(1652,1575),
               (1631,1535),(1611,1499)]],
       's5': [[(1236,1380),(1313,1767),(1292,1776),(1125,1428),(1161,1404),(1198,1391)],
              [(1181,1060),(1230,1323),(1187,1336),(1154,1353),(1105,1382),(987,1130),(1034,1106),(1090,1084),(1129,1070)]],
       's6': [[(1391,1830),(1391,1851),(1668,1866),(1669,1820),(1665,1784),(1663,1758),(1658,1735)],
              [(1696,1720),(1856,1668),(1864,1720),(1867,1771),(1870,1818),(1867,1880),(1705,1870),(1705,1822),(1704,1772)]],
       's7': [[(1283,1911),(1297,1923),(1184,2302),(1136,2285),(1103,2267),(1073,2240)],
              [(882,2527),(1041,2284),(1075,2306),(1108,2333),(1158,2357),(1072,2630),(1014,2612),(966,2584),(920,2556)]],
              (1311,2700),(1273,2708)],
       'd4': [(1696,1281),(1719,1247),(1748,1288),(1771,1328),(1793,1364),(1814,1407),(1830,1439),(1800,1462),(1776,1409),
              (1752,1368),(1728,1331)],
       'd5': [(963,1076),(1016,1052),(1068,1029),(1114,1014),(1169,1000),(1180,1056),(1134,1068),(1092,1080),(1050,1096),
              (1017,1111),(986,1130)],
       'd6': [(1858,1669),(1885,1660),(1893,1708),(1897,1745),(1900,1786),(1901,1833),(1900,1886),(1870,1883),(1870,1819),
              (1869,1761),(1866,1717)],
       'd7': [(884,2528),(930,2561),(979,2593),(1018,2610),(1073,2635),(1053,2685),(984,2661),(929,2629),(884,2599),(851,2574)],
       'd8': [(578,2096),(630,2078),(640,2135),(663,2208),(684,2263),(721,2335),(686,2363),(649,2302),(625,2242),(602,2180)],
       'd9': [(772,1247),(809,1287),(770,1335),(739,1384),(711,1440),(675,1513),(631,1491),(660,1424),(690,1371),(720,1318)],
       'd10': [(1870,1884),(1898,1885),(1894,1944),(1890,1991),(1880,2039),(1872,2081),(1862,2114),(1835,2102),(1851,2046),
               (1857,1990),(1867,1936)],
       'd11': [(563,1788),(615,1793),(613,1867),(613,1939),(622,2006),(631,2072),(582,2094),(566,2018),(560,1947),(559,1873)],
       'd12': [(956,1082),(978,1130),(942,1154),(893,1186),(852,1226),(802,1281),(772,1249),(821,1188),(872,1139),(916,1109)],
       'd13': [(1799,1463),(1828,1439),(1846,1490),(1863,1540),(1874,1585),(1885,1649),(1858,1658),(1842,1587),(1826,1537),
               (1816,1499)],
       'd14': [(633,1490),(672,1510),(652,1560),(636,1618),(622,1679),(617,1731),(610,1789),(562,1787),(574,1680),(594,1598),
               (610,1545)],
       'd15': [(1835,2102),(1861,2114),(1847,2168),(1826,2215),(1811,2258),(1777,2326),(1750,2301),(1783,2238),(1806,2189),
               (1819,2146)],
       'd16': [(680,2367),(724,2335),(744,2376),(775,2415),(800,2453),(839,2490),(878,2526),(850,2572),(789,2520),(746,2471),
               (711,2422)],
       'd17': [(1625,2476),(1643,2511),(1603,2548),(1560,2587),(1520,2616),(1472,2644),(1466,2594),(1516,2562),(1556,2533),
               (1586,2507)],
       'd18': [(1571,1102),(1556,1142),(1594,1170),(1627,1203),(1656,1232),(1695,1279),(1714,1249),(1683,1203),(1650,1167),
               (1612,1133)],
       'd19': [(1073,2633),(1054,2686),(1113,2697),(1167,2706),(1214,2712),(1266,2708),(1273,2651),(1213,2654),(1163,2652),
               (1112,2644)],
       'd20': [(1174,998),(1246,996),(1312,999),(1373,1010),(1373,1063),(1326,1053),(1272,1045),(1217,1048),(1181,1052)]}

# %%
def inside_zone(zone_no, point, h_s=h_s):
    p = Point(point[0], point[1])
    if zone_no == 'b25':
        coord = h_s[zone_no]
        coord2 = h_s['b50']
        poly = Polygon(coord)
        poly2 = Polygon(coord2)
        if p.within(poly) and not p.within(poly2):
            return True
        else:
            return False


    coord = h_s[zone_no]
    if len(coord) > 2:   #zones are b50, t or d
        poly = Polygon(coord)
        if p.within(poly):
            return True
        else:
            return False


    if len(coord) == 2:        #zones are s
        poly = Polygon(coord[0])
        poly2 = Polygon(coord[1])
        if p.within(poly) or p.within(poly2):
            return True
        else:
            return False
    return False

# %%
def which_zone(point):
    zones = h_s.keys()
    for zone in zones:
        if inside_zone(zone, point):
            return zone

# %%
u = np.array([31, 255, 255])
l = np.array([8, 42, 57])

# %%
masked = []

for img in images_t:
    img_hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    masked.append(cv.inRange(img_hsv, l, u))

# %%
imgs_highlighted = []

for i, img in enumerate(masked):
    line_coord = cv.HoughLinesP(img, 1, np.pi / 180, 40, minLineLength=51, maxLineGap=4)
    for coords in line_coord:
        #print(line)
        line = coords[0]
        cv.line(images_t[i], (line[0], line[1]), (line[2], line[3]), (255, 255, 0), 11)

# %%
binary_highlighted = []

for img in images_t:
    binary_highlighted.append(cv.inRange(img, (255, 255, 0), (255, 255, 0)))       #(255, 255, 0) is the high and low hsv value

# %%
binary_dilated = []
for img in binary_highlighted:
    binary_dilated.append(cv.dilate(img, np.ones((5, 5), np.uint8), iterations=1))

# %%
positions_all = []                 #darts positions on darts board
nr = []                            #number of darts per image
minArea = 3000                     #keep only shapes of area bigger than threshold, ignore noise

# %%
for img in binary_dilated:
    contours, hierarchy = cv.findContours(img, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)

    positions = []
    for contour in contours:
        area = cv.contourArea(contour)
        if area > minArea:
            M = cv.moments(contour)
            centroid = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))
            angle = 0.5 * np.arctan2(2 * M["mu11"], M["mu20"] - M["mu02"])
            x = -131 * np.cos(angle) + centroid[0]
            y = -131 * np.sin(angle) + centroid[1]
            pos = which_zone((x, y))
            positions.append(pos)
    nr.append(len(positions))
    positions_all.append(positions)

# %%
try:
    os.mkdir("./Stegarescu_Ana-Maria_507/Task2")
except:
    print("Directory already exists")

# %%
for i in range(25):
    folder = 'Stegarescu_Ana-Maria_507/Task2'

    file = ''
    if i < 9:
        file = folder + '/0' + str(i+1) + '_predicted.txt'
    else:
        file = folder + "/" + str(i+1) + '_predicted.txt'
    f = open(file, "w")
    f.write(str(nr[i]) + "\n")
    for j, pos in enumerate(positions_all[i]):
        if j + 1 < len(positions_all[i]):
            f.write(str(pos) + "\n")
        else:
            f.write(str(pos))
    f.close()

# %%
for i in range(25):
    print(i+1, positions_all[i])
# Out:
# 1 ['d5']
# 2 ['s19', 't14', 's13']
# 3 ['s6']
# 4 ['s10', 's13', 't9']
# 5 ['s11', 't13']
# 6 ['s7', 's10', 's6', 't20']
# 7 ['s8', 's15']
# 8 ['t17', 's9']
# 9 ['s10', 't12', 's1']
# 10 ['s19', 's6', 's9']
# 11 ['t15', 't18']
# 12 ['s20']
# 13 ['d10']
# 14 ['s19']
# 15 ['t11', 's4']
# 16 ['s16', 't12']
# 17 ['s10']
# 18 [None, 's10', 's6', 's9']
# 19 ['s16']
# 20 [None, 's4', 's18']
# 21 ['s15', 's11']
# 22 [None, 's13', 's12']
# 23 [None, 's5']
# 24 ['s16', 'd10']
# 25 ['s7', None]
